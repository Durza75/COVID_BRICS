# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

#  Import and read the charity_data.csv.
import pandas as pd 
# countries_df = pd.read_csv("./Resources/GDP_BRICS_US_Final_Project_current.csv")
global_cases_df = pd.read_csv("./Resources/confirmed_global_cases.csv")
global_cases_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/2020  1/23/2020  \
# 0            NaN    Afghanistan  33.93911  67.709953          0          0
# 1            NaN        Albania  41.15330  20.168300          0          0
# 2            NaN        Algeria  28.03390   1.659600          0          0
# 3            NaN        Andorra  42.50630   1.521800          0          0
# 4            NaN         Angola -11.20270  17.873900          0          0
#
#    1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  12/27/2021  12/28/2021  \
# 0          0          0          0          0  ...      157967      157998
# 1          0          0          0          0  ...      207709      208352
# 2          0          0          0          0  ...      216930      217265
# 3          0          0          0          0  ...       22332       22540
# 4          0          0          0          0  ...       71752       76787
#
# ...

# %%
# Looking at the size of our data
global_cases_df.shape
# Out:
# (280, 719)

# %%
# Removing "Province/State" column, since it is irrelevant. Only need country
global_cases_df_drop = global_cases_df.drop(['Province/State'], axis=1)
global_cases_df_drop
# Out:
#          Country/Region        Lat        Long  1/22/2020  1/23/2020  \
# 0           Afghanistan  33.939110   67.709953          0          0
# 1               Albania  41.153300   20.168300          0          0
# 2               Algeria  28.033900    1.659600          0          0
# 3               Andorra  42.506300    1.521800          0          0
# 4                Angola -11.202700   17.873900          0          0
# ..                  ...        ...         ...        ...        ...
# 275             Vietnam  14.058324  108.277199          0          2
# 276  West Bank and Gaza  31.952200   35.233200          0          0
# 277               Yemen  15.552727   48.516388          0          0
# 278              Zambia -13.133897   27.849332          0          0
# 279            Zimbabwe -19.015438   29.154857          0          0
#
#      1/24/2020  1/25/2020  1/26/2020  1/27/2020  1/28/2020  ...  12/27/2021  \
# ...

# %%
# Collapse the dates from by day to by month
