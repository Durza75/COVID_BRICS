# %%
import pandas as pd
import pandas_datareader as pdr

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from matplotlib import rcParams
rcParams["figure.figsize"] = 8,6

# %%
inflation_df = pd.read_excel("inflation.xlsx", index_col=0)

# %%
inflation_df.head(25)
# Out:
#       Brazil  China  India  Russia  South_Africa  United_States
# Time
# 2000     7.0    0.3    4.0    20.8           5.3            3.4
# 2001     6.8    0.7    3.8    21.5           5.7            2.8
# 2002     8.5   -0.7    4.3    15.8           9.5            1.6
# 2003    14.7    1.1    3.8    13.7           5.7            2.3
# 2004     6.6    3.8    3.8    10.9          -0.7            2.7
# 2005     6.9    1.8    4.2    12.7           2.1            3.4
# 2006     4.2    1.6    5.8     9.7           3.2            3.2
# 2007     3.6    4.8    6.4     9.0           6.2            2.9
# 2008     5.7    5.9    8.3    14.1          10.1            3.8
# 2009     4.9   -0.7   10.9    11.6           7.3           -0.4
# 2010     5.0    3.2   12.0     6.8           4.1            1.6
# 2011     6.6    5.6    8.9     8.4           5.0            3.2
# 2012     5.4    2.6    9.3     5.1           5.7            2.1
# 2013     6.2    2.6   11.1     6.8           5.8            1.5
# ...

# %%
inflation_df.index
# Out:
# Int64Index([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#             2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#            dtype='int64', name='Time')

# %%
plt.xlabel("Year")
plt.ylabel("Inflation")
plt.plot(inflation_df.India, label="India")
plt.plot(inflation_df.China, label="China")
plt.plot(inflation_df.Brazil, label="Brazil")
plt.plot(inflation_df.United_States, label="United_States")
plt.plot(inflation_df.Russia, label="Russia")
plt.plot(inflation_df.South_Africa, label="South_Africa")
plt.legend();
plt.title("Inflation Rates in BRICS_US");
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.plot(inflation_df.United_States, label="United_States")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
